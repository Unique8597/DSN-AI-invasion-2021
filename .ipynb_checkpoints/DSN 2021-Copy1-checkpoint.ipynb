# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, LabelEncoder, StandardScaler, Normalizer
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import f1_score,classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #### Importing my dataset

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
sample_submission = pd.read_csv('sample_submission.csv')

# %%
train.head()
# Out:
#          customer_id  age          job  marital          education  default  \
# 0  customer_id_39075   31       admin.  married  university.degree       no
# 1  customer_id_34855   31   technician   single  university.degree       no
# 2   customer_id_7107   47  blue-collar  married           basic.6y  unknown
# 3  customer_id_31614   36     services  married  university.degree       no
# 4  customer_id_34878   34       admin.   single        high.school       no
#
#   housing loan    contact month     ...     campaign  pdays  previous  \
# 0      no   no   cellular   dec     ...            3    999         1
# 1      no   no  telephone   may     ...            4    999         0
# 2     yes   no  telephone   may     ...            2    999         0
# 3      no   no   cellular   may     ...            1    999         1
# 4      no   no   cellular   may     ...            9    999         0
#
#       poutcome  emp_var_rate cons_price_idx  cons_conf_idx  euribor3m  \
# ...

# %% [markdown]
# #### Counting values of train and test

# %%
train.subscribed.value_counts()
# Out:
# 0    25580
# 1     3251
# Name: subscribed, dtype: int64

# %%
train.shape
# Out:
# (28831, 22)

# %%
test.shape
# Out:
# (12357, 21)

# %% [markdown]
# #### getting number columns and categorical columns

# %%
no_cols = train.describe().columns

# %%
len(no_cols)
# Out:
# 11

# %%
all_columns  =  test.columns
cat_col = [col for col in all_columns if col not in no_cols]

# %%
del cat_col[0]

# %% [markdown]
# #### Converting categorical columns

# %%
for cat in cat_col:
    lb = LabelEncoder().fit(train[cat])
    train[cat] = lb.transform(train[cat])
    test[cat] = lb.transform(test[cat])

# %% [markdown]
# #### Dropping unuseful data columns

# %%
X = train.drop('customer_id', axis = 1)
X = X.drop('contact', axis = 1)
test = test.drop('customer_id', axis = 1)
test = test.drop('contact', axis = 1)

# %%
X.head(10)
# Out:
#    age  job  marital  education  default  housing  loan  month  day_of_week  \
# 0   31    0        1          6        0        0     0      2            1
# 1   31    9        2          6        0        0     0      6            0
# 2   47    1        1          1        1        2     0      6            2
# 3   36    7        1          6        0        0     0      6            2
# 4   34    0        2          3        0        0     0      6            0
# 5   48    2        1          6        0        2     2      7            1
# 6   34    1        2          0        1        0     0      3            3
# 7   34    9        2          5        0        0     0      4            1
# 8   39   10        2          6        0        2     0      5            0
# 9   40    9        2          5        0        1     1      4            0
#
#     duration  campaign  pdays  previous  poutcome  emp_var_rate  \
# 0   1.283333         3    999         1         0         -2.97
# ...

# %% [markdown]
# #### Scaling train dataset

# %%
stad = MinMaxScaler()
stad.fit(X)
new_train = stad.transform(X)

# %% [markdown]
# #### Dropping target column

# %%
y_target = X['subscribed']

# %% [markdown]
# #### Train test split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, y_target, test_size = 0.3, random_state = 0)

# %%
X_train.head(30)
# Out:
#        age  job  marital  education  default  housing  loan  month  \
# 7002    36    1        1          0        1        2     0      6
# 19710   52    9        1          6        0        2     0      1
# 25388   40    9        2          3        0        2     0      6
# 17203   50    1        1          5        0        2     0      1
# 1881    31    0        2          2        0        0     0      6
# 21433   76    5        1          3        0        0     0      1
# 11781   56    0        1          3        0        0     0      6
# 16191   31    9        2          6        0        2     2      1
# 6860    32    7        1          3        0        0     0      7
# 25648   39    7        1          3        0        0     0      6
# 26170   35    7        1          3        0        0     0      6
# 5426    31    8        2          3        0        2     0      3
# 19484   33    8        2          3        0        2     0      0
# ...

# %%
shuffled_df = X_train.sample(frac = 1, random_state = 0)

# %%
subscribed_df = shuffled_df.loc[shuffled_df['subscribed']==1]

# %%
n_subscribed_df = shuffled_df.loc[shuffled_df['subscribed']==0].sample(n= 12000, random_state = 42)

# %%
normalized_df = pd.concat([subscribed_df, n_subscribed_df])

# %%
# Out:
# 7002     0
# 19710    0
# 25388    0
# 17203    0
# 1881     0
# Name: subscribed, dtype: int64

# %%
new_X = normalized_df.drop('subscribed', axis = 1)

# %%
new_X.head()
# Out:
#        age  job  marital  education  default  housing  loan  month  \
# 12558   87    5        0          0        1        2     0      2
# 24961   49    0        1          6        0        0     0      1
# 25209   66    5        1          5        0        0     0      4
# 189     55    9        0          3        0        0     0      7
# 10634   33    0        2          6        0        2     0      1
#
#        day_of_week   duration  campaign  pdays  previous  poutcome  \
# 12558            1   5.350000         3      6         1         2
# 24961            4   7.833333         1      4         2         2
# 25209            3   3.700000         1    999         3         0
# 189              2   8.850000         1    999         0         1
# 10634            3  17.200000         2    999         0         1
#
#        emp_var_rate  cons_price_idx  cons_conf_idx  euribor3m  nr_employed
# 12558         -2.97         46.3565         -23.10      1.717       5023.5
# ...

# %%
plt.figure(figsize = (6,6))
sns.countplot('subscribed', data = normalized_df)
plt.show()

# %% [markdown]
# #### Model and fitting

# %%
reg = GradientBoostingClassifier(random_state = 42)
reg.fit(new_X, Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-102-273cb658795f> in <module>()
#       1 reg = GradientBoostingClassifier(random_state = 42)
# ----> 2 reg.fit(new_X, Y_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\gradient_boosting.py in fit(self, X, y, sample_weight, monitor)
#     977
#     978         # Check input
# --> 979         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'], dtype=DTYPE)
#     980         n_samples, self.n_features_ = X.shape
#     981         if sample_weight is None:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     550         y = y.astype(np.float64)
#     551
# --> 552     check_consistent_length(X, y)
# ...

# %% [markdown]
# #### Prediction

# %%
new_reg = reg.predict(X_test)

# %%
pd.Series(new_reg).value_counts()
# Out:
# 0    7638
# 1    1012
# dtype: int64

# %% [markdown]
# #### f1 score

# %%
f1_score(Y_test, new_reg)
# Out:
# 1.0

# %%
print(classification_report(Y_test, new_reg))
# Out:
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      7638
#           1       1.00      1.00      1.00      1012
#
# avg / total       1.00      1.00      1.00      8650

# %% [markdown]
# #### main test

# %%
new_reg_2 = reg.predict(test)

# %% [markdown]
# #### Submission

# %%
sample_submission.subscribed = new_reg_2

# %%
sample_submission.subscribed.value_counts()
# Out:
# 0    11000
# 1     1357
# Name: subscribed, dtype: int64
